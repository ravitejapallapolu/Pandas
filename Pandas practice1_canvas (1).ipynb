# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df =pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Indicator                4656 non-null   object
#  1   PUBLISH STATES           4656 non-null   object
#  2   Year                     4656 non-null   int64
#  3   WHO region               4656 non-null   object
#  4   World Bank income group  4656 non-null   object
#  5   Country                  4656 non-null   object
#  6   Sex                      4656 non-null   object
#  7   Display Value            4656 non-null   int64
#  8   Numeric                  4656 non-null   float64
#  9   Low                      0 non-null      float64
#  10  High                     0 non-null      float64
#  11  Comments                 0 non-null      float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %%
df1 =pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')
df1.head(2)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...  WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %%
#2. Get the row names from the above files.
np.array(df.index)
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655], dtype=int64)

# %%
df.head()
# Out:
#                            Indicator PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %%
df.columns.rename(name='Indicator_1',inplace=True)

# %%
df['Indicator_id'] = df['Indicator']
df.drop('Indicator',inplace=True,axis=1)

# %%
df.head()
# Out:
#                            Indicator PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %%
df.rename(columns={'Indicator':'Indicator_id'},inplace=True)
df.head()
# Out:
#                         Indicator_id PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %%
df.rename(columns={'PUBLISH STATES':'Publish States','WHO region':'WHO Region'},inplace=True)

# %%
df.sort_values(['Year','Country','Indicator_id','WHO Region','Publish States'],ascending=True).head()
# Out:
#                            Indicator_id Publish States  Year  \
# 555   Life expectancy at age 60 (years)      Published  1990
# 1395  Life expectancy at age 60 (years)      Published  1990
# 2959  Life expectancy at age 60 (years)      Published  1990
# 554    Life expectancy at birth (years)      Published  1990
# 965    Life expectancy at birth (years)      Published  1990
#
#                  WHO Region World Bank income group      Country         Sex  \
# 555   Eastern Mediterranean              Low-income  Afghanistan      Female
# 1395  Eastern Mediterranean              Low-income  Afghanistan  Both sexes
# 2959  Eastern Mediterranean              Low-income  Afghanistan        Male
# 554   Eastern Mediterranean              Low-income  Afghanistan  Both sexes
# 965   Eastern Mediterranean              Low-income  Afghanistan        Male
#
#       Display Value  Numeric  Low  High  Comments
# 555              15     15.0  NaN   NaN       NaN
# ...

# %%
df.head()
# Out:
#                         Indicator_id Publish States  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO Region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %%
a=df.pop('Country')
df.insert(0,column='Country', value=a)
df.head()
# Out:
#                 Country                       Indicator_id Publish States  \
# 0               Andorra   Life expectancy at birth (years)      Published
# 1               Andorra   Life expectancy at birth (years)      Published
# 2               Andorra  Life expectancy at age 60 (years)      Published
# 3               Andorra  Life expectancy at age 60 (years)      Published
# 4  United Arab Emirates   Life expectancy at birth (years)      Published
#
#    Year             WHO Region World Bank income group         Sex  \
# 0  1990                 Europe             High-income  Both sexes
# 1  2000                 Europe             High-income  Both sexes
# 2  2012                 Europe             High-income      Female
# 3  2000                 Europe             High-income  Both sexes
# 4  2012  Eastern Mediterranean             High-income      Female
#
#    Display Value  Numeric  Low  High  Comments
# 0             77     77.0  NaN   NaN       NaN
# ...

# %%
np.array(df['Country'])
# Out:
# array(['Andorra', 'Andorra', 'Andorra', ..., 'South Africa', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %%
df.iloc[[11,24,37]]
# Out:
#               Country                       Indicator_id Publish States  Year  \
# 11            Austria   Life expectancy at birth (years)      Published  2012
# 24  Brunei Darussalam  Life expectancy at age 60 (years)      Published  2012
# 37             Cyprus  Life expectancy at age 60 (years)      Published  2012
#
#          WHO Region World Bank income group     Sex  Display Value  Numeric  \
# 11           Europe             High-income  Female             83     83.0
# 24  Western Pacific             High-income  Female             21     21.0
# 37           Europe             High-income  Female             26     26.0
#
#     Low  High  Comments
# 11  NaN   NaN       NaN
# 24  NaN   NaN       NaN
# 37  NaN   NaN       NaN

# %%
df[~ df.index.isin([5,12,23,56])].head(10)
# Out:
#                  Country                       Indicator_id Publish States  \
# 0                Andorra   Life expectancy at birth (years)      Published
# 1                Andorra   Life expectancy at birth (years)      Published
# 2                Andorra  Life expectancy at age 60 (years)      Published
# 3                Andorra  Life expectancy at age 60 (years)      Published
# 4   United Arab Emirates   Life expectancy at birth (years)      Published
# 6    Antigua and Barbuda  Life expectancy at age 60 (years)      Published
# 7    Antigua and Barbuda  Life expectancy at age 60 (years)      Published
# 8              Australia   Life expectancy at birth (years)      Published
# 9              Australia   Life expectancy at birth (years)      Published
# 10             Australia   Life expectancy at birth (years)      Published
#
#     Year             WHO Region World Bank income group         Sex  \
# 0   1990                 Europe             High-income  Both sexes
# ...

# %%
users =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')
users
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
sessions =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv')
sessions
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4
# 5          6  2012-10-23       4
# 6          7  2012-12-21       3
# 7          8  2013-05-22       4
# 8          9  2013-07-17       4
# 9         10  2016-01-11       4

# %%
products =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv')
products
# Out:
#    ProductID Product  Price
# 0          1       A  14.16
# 1          2       B  33.04
# 2          3       C  10.65
# 3          4       D  10.02
# 4          5       E  29.66

# %%
transactions =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')
transactions
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1
# 5              6      2013-12-23     2.0          5         6
# 6              7      2013-12-30     3.0          4         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3
# 9             10      2016-05-08     3.0          4         4

# %%
transactions.join(users,on='UserID',how='inner',lsuffix='_caller', rsuffix='_other')
# Out:
#    UserID  TransactionID TransactionDate  UserID_caller  ProductID  Quantity  \
# 1     3.0              2      2011-05-26            3.0          4         1
# 2     3.0              3      2011-06-16            3.0          3         1
# 6     3.0              7      2013-12-30            3.0          4         1
# 9     3.0             10      2016-05-08            3.0          4         4
# 3     1.0              4      2012-08-26            1.0          2         3
# 4     2.0              5      2013-06-06            2.0          4         1
# 5     2.0              6      2013-12-23            2.0          5         6
#
#    UserID_other      User  Gender  Registered   Cancelled
# 1             4   Brielle  female  2013-07-17         NaN
# 2             4   Brielle  female  2013-07-17         NaN
# 6             4   Brielle  female  2013-07-17         NaN
# 9             4   Brielle  female  2013-07-17         NaN
# 3             2     Pedro    male  2010-08-01  2010-08-08
# ...

# %%
transactions
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1
# 5              6      2013-12-23     2.0          5         6
# 6              7      2013-12-30     3.0          4         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3
# 9             10      2016-05-08     3.0          4         4

# %%
transactions[~transactions['UserID'].isin(users['UserID'])]
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3

# %%
#transactions.join(users,on='UserID',how='inner')
transactions.merge(users,how='inner',left_on='UserID',right_on='UserID')
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26     3.0          4         1  Caroline
# 1              3      2011-06-16     3.0          3         1  Caroline
# 2              7      2013-12-30     3.0          4         1  Caroline
# 3             10      2016-05-08     3.0          4         4  Caroline
# 4              4      2012-08-26     1.0          2         3   Charles
# 5              5      2013-06-06     2.0          4         1     Pedro
# 6              6      2013-12-23     2.0          5         6     Pedro
#
#    Gender  Registered   Cancelled
# 0  female  2012-10-23  2016-06-07
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3  female  2012-10-23  2016-06-07
# 4    male  2012-12-21         NaN
# 5    male  2010-08-01  2010-08-08
# 6    male  2010-08-01  2010-08-08

# %%
transactions.merge(users,how='outer',left_on='UserID',right_on='UserID')
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0             1.0      2010-08-21     7.0        2.0       1.0       NaN
# 1             9.0      2015-04-24     7.0        4.0       3.0       NaN
# 2             2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 3             3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 4             7.0      2013-12-30     3.0        4.0       1.0  Caroline
# 5            10.0      2016-05-08     3.0        4.0       4.0  Caroline
# 6             4.0      2012-08-26     1.0        2.0       3.0   Charles
# 7             5.0      2013-06-06     2.0        4.0       1.0     Pedro
# 8             6.0      2013-12-23     2.0        5.0       6.0     Pedro
# 9             8.0      2014-04-24     NaN        2.0       3.0       NaN
# 10            NaN             NaN     4.0        NaN       NaN   Brielle
# 11            NaN             NaN     5.0        NaN       NaN  Benjamin
#
# ...

# %%
sessions
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4
# 5          6  2012-10-23       4
# 6          7  2012-12-21       3
# 7          8  2013-05-22       4
# 8          9  2013-07-17       4
# 9         10  2016-01-11       4

# %%
transactions
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1
# 5              6      2013-12-23     2.0          5         6
# 6              7      2013-12-30     3.0          4         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3
# 9             10      2016-05-08     3.0          4         4

# %%
users
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
pd.merge(transactions,users,how='inner',left_on=['UserID','TransactionDate'],right_on=['UserID','Registered'])
# Out:
# Empty DataFrame
# Columns: [TransactionID, TransactionDate, UserID, ProductID, Quantity, User, Gender, Registered, Cancelled]
# Index: []

# %%
products
# Out:
#    ProductID Product  Price
# 0          1       A  14.16
# 1          2       B  33.04
# 2          3       C  10.65
# 3          4       D  10.02
# 4          5       E  29.66

# %%
users
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
pd.cross(users['UserID'],products['ProductID'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-142-612ee15b6022> in <module>
# ----> 1 pd.cross(users['UserID'],products['ProductID'])
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     261             return _SparseArray
#     262
# --> 263         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     264
#     265
#
# AttributeError: module 'pandas' has no attribute 'cross'

# %%
b=pd.DataFrame(users['UserID'])
b
users['UserID']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# k    1
# Name: UserID, dtype: int64

# %%
products['ProductID']
users['UserID']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# k    1
# Name: UserID, dtype: int64

# %%
pd.merge(users['UserID'],products['ProductID'] ,how='outer')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-147-356dc1807889> in <module>
# ----> 1 pd.merge(users['UserID'],products['ProductID'] ,how='outer')
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      71     validate=None,
#      72 ) -> "DataFrame":
# ---> 73     op = _MergeOperation(
#      74         left,
#      75         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     618             warnings.warn(msg, UserWarning)
#     619
# --> 620         self._validate_specification()
#     621
#     622         # note this function has side effects
#
# ...

# %%
users
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
products
# Out:
#    ProductID Product  Price
# 0          1       A  14.16
# 1          2       B  33.04
# 2          3       C  10.65
# 3          4       D  10.02
# 4          5       E  29.66

# %%
transactions
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1
# 5              6      2013-12-23     2.0          5         6
# 6              7      2013-12-30     3.0          4         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3
# 9             10      2016-05-08     3.0          4         4

# %%
#Determine how much quantity of each product was purchased by each user
l=[]
for i in set(transactions['UserID']):
    if not pd.isnull(i):
        #print(i)
        for j in set(products['ProductID']):
            print(j)
            if (i == transactions['UserID'] and j == transactions['ProductID']):
                print('HAHAH')
                #l.append([i,j,])
    else :
        continue
# Out:
# 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-174-ea750eb9201a> in <module>
#       6         for j in set(products['ProductID']):
#       7             print(j)
# ----> 8             if (i == transactions['UserID'] and j == transactions['ProductID']):
#       9                 print('HAHAH')
#      10                 #l.append([i,j,])
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1476
#    1477     def __nonzero__(self):
# -> 1478         raise ValueError(
#    1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
a = pd.DataFrame(users['UserID'])
a['k']=1

# %%
b = pd.DataFrame(products['ProductID'])
b['k']=1

# %%
c =pd.merge(a,b)
c.drop('k',axis=1,inplace=True)

# %%
c
# Out:
#     UserID  ProductID
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2
# 12       3          3
# 13       3          4
# 14       3          5
# 15       4          1
# 16       4          2
# 17       4          3
# 18       4          4
# 19       4          5
# 20       5          1
# 21       5          2
# 22       5          3
# 23       5          4
# 24       5          5

# %%
d=pd.merge(c,transactions,on=['UserID','ProductID'],how='left')
d.drop(['TransactionID','TransactionDate'],axis=1,inplace=True)

# %%
pd.DataFrame(d.groupby(['UserID','ProductID'])['Quantity'].sum()).reset_index()
# Out:
#     UserID  ProductID  Quantity
# 0        1          1       0.0
# 1        1          2       3.0
# 2        1          3       0.0
# 3        1          4       0.0
# 4        1          5       0.0
# 5        2          1       0.0
# 6        2          2       0.0
# 7        2          3       0.0
# 8        2          4       1.0
# 9        2          5       6.0
# 10       3          1       0.0
# 11       3          2       0.0
# 12       3          3       1.0
# 13       3          4       6.0
# 14       3          5       0.0
# 15       4          1       0.0
# 16       4          2       0.0
# 17       4          3       0.0
# 18       4          4       0.0
# 19       4          5       0.0
# 20       5          1       0.0
# 21       5          2       0.0
# 22       5          3       0.0
# 23       5          4       0.0
# 24       5          5       0.0

# %%
pd.merge(transactions,transactions,on=['UserID'])
# Out:
#     TransactionID_x TransactionDate_x  UserID  ProductID_x  Quantity_x  \
# 0                 1        2010-08-21     7.0            2           1
# 1                 1        2010-08-21     7.0            2           1
# 2                 9        2015-04-24     7.0            4           3
# 3                 9        2015-04-24     7.0            4           3
# 4                 2        2011-05-26     3.0            4           1
# 5                 2        2011-05-26     3.0            4           1
# 6                 2        2011-05-26     3.0            4           1
# 7                 2        2011-05-26     3.0            4           1
# 8                 3        2011-06-16     3.0            3           1
# 9                 3        2011-06-16     3.0            3           1
# 10                3        2011-06-16     3.0            3           1
# 11                3        2011-06-16     3.0            3           1
# ...

# %%
e =pd.merge(users,transactions,how='left',on='UserID')

# %%
e.set_index('UserID',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-238-7afb9446f4e3> in <module>
# ----> 1 e.set_index('UserID',inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['UserID'] are in the columns"

# %%
f =e.index.duplicated(keep='first')
f
# Out:
# array([False, False,  True, False,  True,  True,  True, False, False])

# %%
g =e[~f]

# %%
g.reset_index()
# Out:
#    UserID      User  Gender  Registered   Cancelled  TransactionID  \
# 0       1   Charles    male  2012-12-21         NaN            4.0
# 1       2     Pedro    male  2010-08-01  2010-08-08            5.0
# 2       3  Caroline  female  2012-10-23  2016-06-07            2.0
# 3       4   Brielle  female  2013-07-17         NaN            NaN
# 4       5  Benjamin    male  2010-11-25         NaN            NaN
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26        2.0       3.0
# 1      2013-06-06        4.0       1.0
# 2      2011-05-26        4.0       1.0
# 3             NaN        NaN       NaN
# 4             NaN        NaN       NaN

# %%
e
# Out:
#             User  Gender  Registered   Cancelled  TransactionID  \
# UserID
# 1        Charles    male  2012-12-21         NaN            4.0
# 2          Pedro    male  2010-08-01  2010-08-08            5.0
# 2          Pedro    male  2010-08-01  2010-08-08            6.0
# 3       Caroline  female  2012-10-23  2016-06-07            2.0
# 3       Caroline  female  2012-10-23  2016-06-07            3.0
# 3       Caroline  female  2012-10-23  2016-06-07            7.0
# 3       Caroline  female  2012-10-23  2016-06-07           10.0
# 4        Brielle  female  2013-07-17         NaN            NaN
# 5       Benjamin    male  2010-11-25         NaN            NaN
#
#        TransactionDate  ProductID  Quantity
# UserID
# 1           2012-08-26        2.0       3.0
# 2           2013-06-06        4.0       1.0
# 2           2013-12-23        5.0       6.0
# 3           2011-05-26        4.0       1.0
# 3           2011-06-16        3.0       1.0
# ...

# %%
e.reset_index(inplace=True)

# %%
e.drop_duplicates('UserID').reset_index(drop=True)
e.head(10)
# Out:
#    UserID      User  Gender  Registered   Cancelled  TransactionID  \
# 0       1   Charles    male  2012-12-21         NaN            4.0
# 1       2     Pedro    male  2010-08-01  2010-08-08            5.0
# 2       2     Pedro    male  2010-08-01  2010-08-08            6.0
# 3       3  Caroline  female  2012-10-23  2016-06-07            2.0
# 4       3  Caroline  female  2012-10-23  2016-06-07            3.0
# 5       3  Caroline  female  2012-10-23  2016-06-07            7.0
# 6       3  Caroline  female  2012-10-23  2016-06-07           10.0
# 7       4   Brielle  female  2013-07-17         NaN            NaN
# 8       5  Benjamin    male  2010-11-25         NaN            NaN
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26        2.0       3.0
# 1      2013-06-06        4.0       1.0
# 2      2013-12-23        5.0       6.0
# 3      2011-05-26        4.0       1.0
# 4      2011-06-16        3.0       1.0
# 5      2013-12-30        4.0       1.0
# ...

# %%
e.columns
# Out:
# Index(['UserID', 'User', 'Gender', 'Registered', 'Cancelled', 'TransactionID',
#        'TransactionDate', 'ProductID', 'Quantity'],
#       dtype='object')

# %%
list(e.dropna(thresh=int(e.shape[0] * 0.9), axis=1).columns)
# Out:
# ['UserID', 'User', 'Gender', 'Registered']

# %%
e.shape
# Out:
# (9, 9)

# %%
missing_info = list(e.columns[e.isnull().any()]) 
missing_info
# Out:
# ['Cancelled', 'TransactionID', 'TransactionDate', 'ProductID', 'Quantity']

# %%
e.isnull().any()
# Out:
# UserID             False
# User               False
# Gender             False
# Registered         False
# Cancelled           True
# TransactionID       True
# TransactionDate     True
# ProductID           True
# Quantity            True
# dtype: bool

# %%
for col in missing_info: 
    num_missing = e[e[col].isnull() == True].shape[0]
    print('number missing for column {}: {}'.format(col, num_missing))
# Out:
# number missing for column Cancelled: 3
# number missing for column TransactionID: 2
# number missing for column TransactionDate: 2
# number missing for column ProductID: 2
# number missing for column Quantity: 2

# %%
#count of missing df_ 
for col in missing_info: 
    percent_missing = e[e[col].isnull() == True].shape[0] / e.shape[0] 
    print('percent missing for column {}: {}'.format(col, percent_missing))
# Out:
# percent missing for column Cancelled: 0.3333333333333333
# percent missing for column TransactionID: 0.2222222222222222
# percent missing for column TransactionDate: 0.2222222222222222
# percent missing for column ProductID: 0.2222222222222222
# percent missing for column Quantity: 0.2222222222222222
