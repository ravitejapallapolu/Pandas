# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

# %%
df =pd.read_csv(url,sep='\t')

# %%
df.head(23)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# ...

# %%
df.shape
# Out:
# (4622, 5)

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
df.head(3)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
# 2         1         1              Nantucket Nectar            [Apple]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39

# %%
c= df.groupby('item_name').sum().sort_values(['quantity']).tail(1)
c
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %%
df.groupby('item_name').sum.
# Out:
#   File "<ipython-input-49-50bafb233e28>", line 1
#     df.groupby('item_name').sum.
#                                 ^
# SyntaxError: invalid syntax

# %%
df.groupby('choice_description').sum().sort_values('quantity').tail(1)
# Out:
#                     order_id  quantity  item_price
# choice_description
# [Diet Coke]           123455       159      326.71

# %%
df.head(8)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...

# %%
type(df['item_price'][0])
df['item_price']=df['item_price'].apply(lambda x:float(x[1:]))
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
(df['item_price']*df['quantity']).sum()
# Out:
# 39237.02

# %%
df[['item_name','item_price']]
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4617                          Steak Burrito       11.75
# 4618                          Steak Burrito       11.75
# 4619                     Chicken Salad Bowl       11.25
# 4620                     Chicken Salad Bowl        8.75
# 4621                     Chicken Salad Bowl        8.75
#
# [4622 rows x 2 columns]

# %%
df.duplicated(['item_name','quantity'],keep ='first')
df.drop_duplicates(['item_name','quantity'],inplace=True)
s = df[df['quantity'] ==1]
df
s
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 16           8         1                        Chicken Burrito
# 21          11         1                       Barbacoa Burrito
# 27          14         1                       Carnitas Burrito
# ...

# %%
df[df['quantity'] ==1].count()
#df.dropna(axis=1)
# Out:
# order_id              50
# quantity              50
# item_name             50
# choice_description    38
# item_price            50
# dtype: int64

# %%
s.sort_values(['item_price'],ascending=False)
#What was the quantity of the most expensive item ordered?
df[df['item_price'].max()==df['item_price']]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %%
df[df['item_name']=='Veggie Salad']
# Out:
#       order_id  quantity     item_name  \
# 1694       686         1  Veggie Salad
#
#                                      choice_description  item_price
# 1694  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...        8.49

# %%
df=pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv')
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
df.groupby('continent')['wine_servings'].describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %%
df =pd.read_html('https://github.com/guipsamora/pandas_exercises/blob/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv')
df[0]
# Out:
#     Unnamed: 0  Year  Population     Total  Violent  Property  Murder  \
# 0          NaN  1960   179323175   3384200   288460   3095700    9110
# 1          NaN  1961   182992000   3488000   289390   3198600    8740
# 2          NaN  1962   185771000   3752200   301510   3450700    8530
# 3          NaN  1963   188483000   4109500   316970   3792500    8640
# 4          NaN  1964   191141000   4564600   364220   4200400    9360
# 5          NaN  1965   193526000   4739400   387390   4352000    9960
# 6          NaN  1966   195576000   5223500   430180   4793300   11040
# 7          NaN  1967   197457000   5903400   499930   5403500   12240
# 8          NaN  1968   199399000   6720200   595010   6125200   13800
# 9          NaN  1969   201385000   7410900   661870   6749000   14760
# 10         NaN  1970   203235298   8098000   738820   7359200   16000
# 11         NaN  1971   206212000   8588200   816500   7771700   17780
# ...

# %%
df[0].dropna(axis=1,inplace=True)

# %%
df=df[0]

# %%
df
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
#Convert the type of the column Year to datetime64
#df['Year']
df['Year']=pd.to_datetime(df.Year,format='%Y')
df.head()
# Out:
#         Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 2 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 3 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 4 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     datetime64[ns]
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: datetime64[ns](1), int64(11)
# memory usage: 5.3 KB
#          Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# ...

# %%
df.set_index('Year',inplace=True)

# %%
l=[]
a=[]
for i in range(0,len(df),10):
    print(df.index[i])
    a.append(df.index[i])
    l.append(df[i+0:i+10].sum())
# Out:
# 1960-01-01 00:00:00
# 1970-01-01 00:00:00
# 1980-01-01 00:00:00
# 1990-01-01 00:00:00
# 2000-01-01 00:00:00
# 2010-01-01 00:00:00

# %%
df.head()
df.index[0]
# Out:
# Timestamp('1960-01-01 00:00:00')

# %%
pd.DataFrame(l,index=a)
# Out:
#             Population      Total   Violent   Property  Murder  Forcible_Rape  \
# 1960-01-01  1915053175   49295900   4134930   45160900  106180         236720
# 1970-01-01  2121193298  100991600   9607930   91383800  192230         554570
# 1980-01-01  2371370069  131123369  14074328  117048900  206439         865639
# 1990-01-01  2612825258  136582146  17527048  119053499  211664         998827
# 2000-01-01  2947969117  115012044  13968056  100944369  163068         922499
# 2010-01-01  1570146307   50167967   6072017   44095950   72867         421059
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# 1960-01-01  1633510             2158520  13321100       26547700
# 1970-01-01  4159020             4702120  28486000       53157800
# 1980-01-01  5383109             7619130  33073494       72040253
# 1990-01-01  5748930            10568963  26750015       77679366
# 2000-01-01  4230366             8652124  21565176       67970291
# ...

# %%
#df.resample('10AS').sum()
df.head(0)
# Out:
# Empty DataFrame
# Columns: [Population, Total, Violent, Property, Murder, Forcible_Rape, Robbery, Aggravated_assault, Burglary, Larceny_Theft, Vehicle_Theft]
# Index: []

# %%
df['Population'].resample('10AS').max()
df.head()
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
# 1963-01-01   116470              174210   1086400        2297800
# 1964-01-01   130390              203050   1213200        2514400
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# ...

# %%
#Select the data in rows [3, 4, 8] and in columns ['Murder', 'Robbery']
df.iloc[[3,4,8],[4,6]]
# Out:
#             Murder  Robbery
# Year
# 1963-01-01    8640   116470
# 1964-01-01    9360   130390
# 1968-01-01   13800   262840

# %%
#Select the rows the murder is between 20k and 24k (inclusive)
df[df['Murder'].between(20000,24000)]
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1974-01-01   211392000  10253400   974720   9278700   20710          55400
# 1975-01-01   213124000  11292400  1039710  10252700   20510          56090
# 1979-01-01   220099000  12249500  1208030  11041500   21460          76390
# 1980-01-01   225349264  13408300  1344520  12063700   23040          82990
# 1981-01-01   229146000  13423800  1361820  12061900   22520          82500
# 1982-01-01   231534000  12974400  1322390  11652000   21010          78770
# 1986-01-01   240132887  13211869  1489169  11722700   20613          91459
# 1987-01-01   242282918  13508700  1483999  12024700   20096          91110
# 1988-01-01   245807000  13923100  1566220  12356900   20680          92490
# 1989-01-01   248239000  14251400  1646040  12605400   21500          94500
# 1990-01-01   248709873  14475600  1820130  12655500   23440         102560
# ...

# %%
df[df['Murder']>=20000] and df[df['Murder']<=24000]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-328-a3f18dc7420a> in <module>
# ----> 1 df[df['Murder']>=20000] and df[df['Murder']<=24000]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1476
#    1477     def __nonzero__(self):
# -> 1478         raise ValueError(
#    1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df.groupby('Year')['Murder'].mean()
# Out:
# Year
# 1960-01-01     9110
# 1961-01-01     8740
# 1962-01-01     8530
# 1963-01-01     8640
# 1964-01-01     9360
# 1965-01-01     9960
# 1966-01-01    11040
# 1967-01-01    12240
# 1968-01-01    13800
# 1969-01-01    14760
# 1970-01-01    16000
# 1971-01-01    17780
# 1972-01-01    18670
# 1973-01-01    19640
# 1974-01-01    20710
# 1975-01-01    20510
# 1976-01-01    18780
# 1977-01-01    19120
# 1978-01-01    19560
# 1979-01-01    21460
# 1980-01-01    23040
# 1981-01-01    22520
# 1982-01-01    21010
# 1983-01-01    19310
# 1984-01-01    18690
# 1985-01-01    18980
# 1986-01-01    20613
# 1987-01-01    20096
# 1988-01-01    20680
# 1989-01-01    21500
# 1990-01-01    23440
# 1991-01-01    24700
# 1992-01-01    23760
# 1993-01-01    24530
# 1994-01-01    23330
# 1995-01-01    21610
# 1996-01-01    19650
# 1997-01-01    18208
# 1998-01-01    16914
# 1999-01-01    15522
# 2000-01-01    15586
# 2001-01-01    16037
# 2002-01-01    16229
# 2003-01-01    16528
# 2004-01-01    16148
# ...

# %%
df.sort_values(['Murder', 'Violent'],ascending=[False,True])
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1991-01-01   252177000  14872900  1911770  12961100   24700         106590
# 1993-01-01   257908000  14144800  1926020  12218800   24530         106010
# 1992-01-01   255082000  14438200  1932270  12505900   23760         109060
# 1990-01-01   248709873  14475600  1820130  12655500   23440         102560
# 1994-01-01   260341000  13989500  1857670  12131900   23330         102220
# 1980-01-01   225349264  13408300  1344520  12063700   23040          82990
# 1981-01-01   229146000  13423800  1361820  12061900   22520          82500
# 1995-01-01   262755000  13862700  1798790  12063900   21610          97470
# 1989-01-01   248239000  14251400  1646040  12605400   21500          94500
# 1979-01-01   220099000  12249500  1208030  11041500   21460          76390
# 1982-01-01   231534000  12974400  1322390  11652000   21010          78770
# ...

# %%
#https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/mtcars.csv
df = pd.read_html('https://github.com/vincentarelbundock/Rdatasets/blob/master/csv/datasets/mtcars.csv')
len(df)
# Out:
# 1

# %%
df[0].dropna(axis=1,inplace=True)

# %%
df[0]
# Out:
#              Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df=df[0]

# %%
df.head()
#For each cyl type and each number of gears, find the mean mileage.
# Out:
#           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df.pivot_table(index='cyl',columns='gear',aggfunc='mean',values='mpg')
# Out:
# gear      3       4     5
# cyl
# 4     21.50  26.925  28.2
# 6     19.75  19.750  19.7
# 8     15.05     NaN  15.4
